# %%
import scipy as sp
import scipy.misc
import scipy.ndimage

# %%
f = sp.misc.face(gray=True)

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.imshow(f)

# %%
plt.axis("off")
plt.imshow(f)
